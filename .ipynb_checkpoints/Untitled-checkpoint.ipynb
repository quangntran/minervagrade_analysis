# %%
# from rpy2.robjects import r
import numpy as np

# %%
rstring = """
data <- read.csv("sample_data_for_reporting.csv")
names(data) <- gsub("\\.", "_", names(data))

# renaming  HC and LO tables
names(data)[names(data) == "HC_Name"] <- "LO"
names(data)[names(data) == "Learning_Outcome_Name"] <- "HC"
print(dim(data))


# treat N/A as actual NAs
is.na(data) <- (data == "NA") |(data == "N/A") | (data == "")

# removing incomplete instances with no Score data
data <- data[complete.cases(data$Score),]
print(dim(data))

# resetting the index
rownames(data) <- NULL

## generating week numbers

data$Week <- as.factor(round(as.numeric(as.character(data$Class_Code))))
"""

# %%
LO_IN_ORDER = ["mcanalysis", "mcmodeling", "interpretresults", "professionalism", "pythonimplementation","caanalysis", "camodeling", "networkanalysis","networkmodeling"]
CO_IN_ORDER = ["MonteCarlo","MonteCarlo","Simulations","Simulations","Simulations","Cellular Automata","Cellular Automata","Networks","Networks"]
ASSIGNMENT_TITLES =  ["Elevator simulation",
                        "Traffic simulation",
                        "Network simulation",
                        'Final project proposal',
                        "Final project"]
ASSIGNMENT_WEIGHTS = [2, 6, 6, 0, 10]
DEFAULT_LO_TO_DISPLAY_IN_EVOLUTION = ['networkanalysis', 'networkmodeling']

# %%
np.isnan(list(df['Score'])[1])
# Out:
# True

# %%
import pandas as pd
df = pd.read_csv("sample_data_for_reporting.csv", sep=',',na_values=['NULL', ''])
df.head()
# Out:
#   Student Name  Student ID                               Course Title  \
# 0    Student_1      543055  Modeling, Simulation, and Decision Making
# 1    Student_1      543055  Modeling, Simulation, and Decision Making
# 2    Student_1      543055  Modeling, Simulation, and Decision Making
# 3    Student_1      543055  Modeling, Simulation, and Decision Making
# 4    Student_1      543055  Modeling, Simulation, and Decision Making
#
#   Course Code Class Title  Class Code Assessment Type     Assignment Title  \
# 0       CS166         NaN         NaN      assignment  Elevator simulation
# 1       CS166         NaN         NaN      assignment  Elevator simulation
# 2       CS166         NaN         NaN      assignment  Elevator simulation
# 3       CS166         NaN         NaN      assignment  Elevator simulation
# 4       CS166         NaN         NaN      assignment  Elevator simulation
#
#   Group Assignment Poll Title        Grader Name               Updated Date  \
# 0            False        NaN  Raquel H. Ribeiro  2020-01-24 18:03:47+00:00
# 1            False        NaN  Raquel H. Ribeiro  2020-01-24 18:12:14+00:00
# 2            False        NaN  Raquel H. Ribeiro  2020-01-31 14:13:50+00:00
# 3            False        NaN  Raquel H. Ribeiro  2020-01-31 14:27:00+00:00
# 4            False        NaN  Raquel H. Ribeiro  2020-01-31 14:18:24+00:00
#
#                                              Comment  Score  \
# 0  As requested in the assignment instructions, p...    NaN
# 1  In the future, if you'd like to receive specif...    NaN
# 2  It looks like you all worked well together as ...    4.0
# 3  The code runs, and you’ve provided very clearl...    4.0
# 4  The figures are well color-coded for different...    NaN
#
#   Learning Outcome Name               HC Name
# 0                   NaN                   NaN
# 1                   NaN                   NaN
# 2        responsibility                   NaN
# 3                   NaN  pythonimplementation
# 4                   NaN                   NaN

# %%
import copy
synth_data = copy.copy(df)

# %%
synth_data['Grader Name'] = 'Prof. Ben Affleck'

# %%
random_comments_list = ['This is excellent work!',
                        '"Gone Girl" movie is nice!',
                        'You need to try harder!',
                        'Not quite!',
                        'Exactly!',
                        'You did not complete this part',
                        'I need more details here',
                        'I am not sure what you mean, but it is fine']

# %%
str(abs(hash('Student_2')))[:5]
# Out:
# '48933'

# %%
synth_data['Course Title'] = 'Modeling, Simulation, and Decision Making'

# %%
import datetime
comment_list = []
updated_date_list = []
score_list = []
student_id_list = []
for index, row in synth_data.iterrows():
    # random comment
    comment_list.append(np.random.choice(random_comments_list))
    # random date
    datetime_converted = datetime.datetime.strptime(row['Updated Date'], '%Y-%m-%d %H:%M:%S+00:00')
    datetime_converted = datetime_converted + datetime.timedelta(days=np.random.randint(20))  
    updated_date_list.append(str(datetime_converted)+'+00:00')
    # random score
    if np.isnan(row['Score']):
        score_list.append(row['Score'])
    else:
        new_score = row['Score'] + np.random.choice([-1,0,1])
        if new_score > 5 or new_score < 1:
            new_score = np.random.choice([1,2,3,4,5])
        score_list.append(new_score)
    # modify student id  
    student_id_list.append(str(abs(hash(row['Student Name'])))[:5])
synth_data['Comment'] = comment_list
synth_data['Updated Date'] = updated_date_list
synth_data['Score'] = score_list
synth_data['Student ID'] = student_id_list

# %%
synth_data = synth_data[synth_data['Student Name'].isin(['Student_1', 'Student_2', 'Student_3', 'Student_4', 'Student_5'])]

# %%
synth_data.to_csv('synthetic_data.csv')

# %%
synth_data['Comment'] = 'This is excellent work!'

synth_data['Student ID'] = 1111
# Out:
#     Student Name  Student ID                               Course Title  \
# 0      Student_1        1111  Modeling, Simulation, and Decision Making
# 1      Student_1        1111  Modeling, Simulation, and Decision Making
# 2      Student_1        1111  Modeling, Simulation, and Decision Making
# 3      Student_1        1111  Modeling, Simulation, and Decision Making
# 4      Student_1        1111  Modeling, Simulation, and Decision Making
# 5      Student_1        1111  Modeling, Simulation, and Decision Making
# 6      Student_1        1111  Modeling, Simulation, and Decision Making
# 7      Student_1        1111  Modeling, Simulation, and Decision Making
# 8      Student_1        1111  Modeling, Simulation, and Decision Making
# 9      Student_1        1111  Modeling, Simulation, and Decision Making
# 10     Student_1        1111  Modeling, Simulation, and Decision Making
# 11     Student_1        1111  Modeling, Simulation, and Decision Making
# 12     Student_1        1111  Modeling, Simulation, and Decision Making
# 13     Student_1        1111  Modeling, Simulation, and Decision Making
# 14     Student_1        1111  Modeling, Simulation, and Decision Making
# 15     Student_1        1111  Modeling, Simulation, and Decision Making
# 16     Student_1        1111  Modeling, Simulation, and Decision Making
# 17     Student_1        1111  Modeling, Simulation, and Decision Making
# 18     Student_1        1111  Modeling, Simulation, and Decision Making
# 19     Student_1        1111  Modeling, Simulation, and Decision Making
# 20     Student_1        1111  Modeling, Simulation, and Decision Making
# 21     Student_1        1111  Modeling, Simulation, and Decision Making
# 22     Student_1        1111  Modeling, Simulation, and Decision Making
# 23     Student_1        1111  Modeling, Simulation, and Decision Making
# 24     Student_1        1111  Modeling, Simulation, and Decision Making
# 25     Student_1        1111  Modeling, Simulation, and Decision Making
# 26     Student_1        1111  Modeling, Simulation, and Decision Making
# 27     Student_1        1111  Modeling, Simulation, and Decision Making
# 28     Student_1        1111  Modeling, Simulation, and Decision Making
# 29     Student_1        1111  Modeling, Simulation, and Decision Making
# ..           ...         ...                                        ...
# 913   Student_11        1111  Modeling, Simulation, and Decision Making
# 914   Student_11        1111  Modeling, Simulation, and Decision Making
# 915   Student_11        1111  Modeling, Simulation, and Decision Making
# 916   Student_11        1111  Modeling, Simulation, and Decision Making
# 917   Student_11        1111  Modeling, Simulation, and Decision Making
# 918   Student_11        1111  Modeling, Simulation, and Decision Making
# 919   Student_11        1111  Modeling, Simulation, and Decision Making
# 920   Student_11        1111  Modeling, Simulation, and Decision Making
# 921   Student_11        1111  Modeling, Simulation, and Decision Making
# 922   Student_11        1111  Modeling, Simulation, and Decision Making
# 923   Student_11        1111  Modeling, Simulation, and Decision Making
# 924   Student_11        1111  Modeling, Simulation, and Decision Making
# 925   Student_11        1111  Modeling, Simulation, and Decision Making
# 926   Student_11        1111  Modeling, Simulation, and Decision Making
# 927   Student_11        1111  Modeling, Simulation, and Decision Making
# 928   Student_11        1111  Modeling, Simulation, and Decision Making
# 929   Student_11        1111  Modeling, Simulation, and Decision Making
# 930   Student_11        1111  Modeling, Simulation, and Decision Making
# 931   Student_11        1111  Modeling, Simulation, and Decision Making
# 932   Student_11        1111  Modeling, Simulation, and Decision Making
# 933   Student_11        1111  Modeling, Simulation, and Decision Making
# 934   Student_11        1111  Modeling, Simulation, and Decision Making
# 935   Student_11        1111  Modeling, Simulation, and Decision Making
# 936   Student_11        1111  Modeling, Simulation, and Decision Making
# 937   Student_11        1111  Modeling, Simulation, and Decision Making
# 938   Student_11        1111  Modeling, Simulation, and Decision Making
# 939   Student_11        1111  Modeling, Simulation, and Decision Making
# 940   Student_11        1111  Modeling, Simulation, and Decision Making
# 941   Student_11        1111  Modeling, Simulation, and Decision Making
# 942   Student_11        1111  Modeling, Simulation, and Decision Making
#
#     Course Code                                        Class Title  \
# 0         CS166                                                NaN
# 1         CS166                                                NaN
# 2         CS166                                                NaN
# 3         CS166                                                NaN
# 4         CS166                                                NaN
# 5         CS166                                                NaN
# 6         CS166                                                NaN
# 7         CS166                                                NaN
# 8         CS166                                                NaN
# 9         CS166                                                NaN
# 10        CS166                                                NaN
# 11        CS166                                                NaN
# 12        CS166                                                NaN
# 13        CS166                                                NaN
# 14        CS166                                                NaN
# 15        CS166                                                NaN
# 16        CS166                                                NaN
# 17        CS166                                                NaN
# 18        CS166                                                NaN
# 19        CS166                                                NaN
# 20        CS166                                                NaN
# 21        CS166                                                NaN
# 22        CS166                                                NaN
# 23        CS166                                                NaN
# 24        CS166                                                NaN
# 25        CS166                                                NaN
# 26        CS166                                                NaN
# 27        CS166                                                NaN
# 28        CS166                                                NaN
# 29        CS166                                                NaN
# ..          ...                                                ...
# 913       CS166                                                NaN
# 914       CS166                                                NaN
# 915       CS166                                                NaN
# 916       CS166                                                NaN
# 917       CS166                                                NaN
# 918       CS166  CS166 Session 2.1 - Introduction to cellular a...
# 919       CS166  CS166 Session 2.1 - Introduction to cellular a...
# 920       CS166   CS166 Session 2.2 - Simulating cellular automata
# 921       CS166       CS166 Session 3.1 - Mean-field approximation
# 922       CS166       CS166 Session 3.1 - Mean-field approximation
# 923       CS166  CS166 Session 3.2 - Percolation and renormaliz...
# 924       CS166     CS166 Session 4.2 - Case study: Traffic flow 2
# 925       CS166       CS166 Session 5.2 - Introduction to networks
# 926       CS166           CS166 Session 6.2 - Dynamics on networks
# 927       CS166  CS166 Session 7.1 - Dynamics of network structure
# 928       CS166              CS166 Session 7.2 - Adaptive networks
# 929       CS166  CS166 Session 8.1 - Network metrics and percol...
# 930       CS166  CS166 Session 8.1 - Network metrics and percol...
# 931       CS166  CS166 Session 8.2 - PageRank in citation networks
# 932       CS166  CS166 Session 8.2 - PageRank in citation networks
# 933       CS166       CS166 Session 9.1 - Mean field approximation
# 934       CS166        CS166 Session 9.2 - Networks unit synthesis
# 935       CS166  CS166 Session 10.1 - Simulations with random n...
# 936       CS166  CS166 Session 10.2 - Random numbers from simul...
# 937       CS166             CS166 Session 12.1 - The Ising model 1
# 938       CS166  CS166 Session 12.2 - The Metropolis-Hastings m...
# 939       CS166             CS166 Session 13.1 - The Ising model 2
# 940       CS166       CS166 Session 13.2 - Random walks in finance
# 941       CS166           CS166 Session 14.1 - The Kelly criterion
# 942       CS166  CS166 Session 14.2 - MCMC methods for paramete...
#
#      Class Code Assessment Type        Assignment Title Group Assignment  \
# 0           NaN      assignment     Elevator simulation            False
# 1           NaN      assignment     Elevator simulation            False
# 2           NaN      assignment     Elevator simulation            False
# 3           NaN      assignment     Elevator simulation            False
# 4           NaN      assignment     Elevator simulation            False
# 5           NaN      assignment     Elevator simulation            False
# 6           NaN      assignment     Elevator simulation            False
# 7           NaN      assignment     Elevator simulation            False
# 8           NaN      assignment     Elevator simulation            False
# 9           NaN      assignment     Elevator simulation            False
# 10          NaN      assignment     Elevator simulation            False
# 11          NaN      assignment     Elevator simulation            False
# 12          NaN      assignment     Elevator simulation            False
# 13          NaN      assignment      Traffic simulation            False
# 14          NaN      assignment      Traffic simulation            False
# 15          NaN      assignment      Traffic simulation            False
# 16          NaN      assignment      Traffic simulation            False
# 17          NaN      assignment      Traffic simulation            False
# 18          NaN      assignment      Traffic simulation            False
# 19          NaN      assignment      Traffic simulation            False
# 20          NaN      assignment      Traffic simulation            False
# 21          NaN      assignment      Traffic simulation            False
# 22          NaN      assignment      Traffic simulation            False
# 23          NaN      assignment      Traffic simulation            False
# 24          NaN      assignment      Traffic simulation            False
# 25          NaN      assignment      Traffic simulation            False
# 26          NaN      assignment      Traffic simulation            False
# 27          NaN      assignment      Traffic simulation            False
# 28          NaN      assignment      Traffic simulation            False
# 29          NaN      assignment      Traffic simulation            False
# ..          ...             ...                     ...              ...
# 913         NaN      assignment      Network simulation            False
# 914         NaN      assignment      Network simulation            False
# 4    This is excellent work!    NaN                   NaN
# 5    This is excellent work!    4.0                   NaN
# 6    This is excellent work!    NaN                   NaN
# 7    This is excellent work!    NaN                   NaN
# 8    This is excellent work!    4.0       professionalism
# 9    This is excellent work!    NaN                   NaN
# 10   This is excellent work!    1.0              critique
# 11   This is excellent work!    2.0              modeling
# 12   This is excellent work!    5.0                   NaN
# 13   This is excellent work!    4.0          organization
# 14   This is excellent work!    NaN                   NaN
# 15   This is excellent work!    NaN                   NaN
# 16   This is excellent work!    NaN                   NaN
# 17   This is excellent work!    NaN                   NaN
# 18   This is excellent work!    NaN                   NaN
# 19   This is excellent work!    4.0                   NaN
# 20   This is excellent work!    2.0       professionalism
# 21   This is excellent work!    NaN                   NaN
# 22   This is excellent work!    2.0                   NaN
# 23   This is excellent work!    NaN                   NaN
# 24   This is excellent work!    4.0                   NaN
# 25   This is excellent work!    NaN                   NaN
# 26   This is excellent work!    NaN                   NaN
# 27   This is excellent work!    4.0                   NaN
# 28   This is excellent work!    3.0                   NaN
# 29   This is excellent work!    3.0                   NaN
# ..                       ...    ...                   ...
# 913  This is excellent work!    NaN                   NaN
# 914  This is excellent work!    2.0        systemdynamics
# 915  This is excellent work!    3.0         distributions
# 916  This is excellent work!    3.0              modeling
# 917  This is excellent work!    NaN                   NaN
# 918  This is excellent work!    5.0                   NaN
# 919  This is excellent work!    NaN                   NaN
# 920  This is excellent work!    2.0                   NaN
# 921  This is excellent work!    4.0                   NaN
# 922  This is excellent work!    NaN                   NaN
# 923  This is excellent work!    3.0                   NaN
# 924  This is excellent work!    5.0                   NaN
# 925  This is excellent work!    5.0                   NaN
# 926  This is excellent work!    4.0                   NaN
# 927  This is excellent work!    2.0                   NaN
# 928  This is excellent work!    2.0                   NaN
# 929  This is excellent work!    3.0                   NaN
# 930  This is excellent work!    NaN                   NaN
# 931  This is excellent work!    4.0                   NaN
# 932  This is excellent work!    NaN                   NaN
# 933  This is excellent work!    3.0                   NaN
# 934  This is excellent work!    5.0                   NaN
# 935  This is excellent work!    4.0                   NaN
# 936  This is excellent work!    4.0                   NaN
# 937  This is excellent work!    3.0                   NaN
# 938  This is excellent work!    3.0                   NaN
# 939  This is excellent work!    2.0                   NaN
# 940  This is excellent work!    3.0                   NaN
# 941  This is excellent work!    4.0                   NaN
# 942  This is excellent work!    4.0                   NaN
#
#                   HC Name
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3    pythonimplementation
# 4                     NaN
# 5        interpretresults
# 6                     NaN
# 7                     NaN
# 8                     NaN
# 9                     NaN
# 10                    NaN
# 11                    NaN
# 12        professionalism
# 13                    NaN
# 14                    NaN
# 15                    NaN
# 16                    NaN
# 17                    NaN
# 18                    NaN
# 19        professionalism
# 20                    NaN
# 21                    NaN
# 22       interpretresults
# 23                    NaN
# 24       interpretresults
# 25                    NaN
# 26                    NaN
# 27   pythonimplementation
# 28   pythonimplementation
# 29             camodeling
# ..                    ...
# 913                   NaN
# 914                   NaN
# 915                   NaN
# 916                   NaN
# 917                   NaN
# 918            camodeling
# 919                   NaN
# 920  pythonimplementation
# 921            caanalysis
# 922                   NaN
# 923            caanalysis
# 924            camodeling
# 925       networkmodeling
# 926      interpretresults
# 927       networkmodeling
# 928       networkmodeling
# 929       networkanalysis
# 930                   NaN
# 931      interpretresults
# 932                   NaN
# 933  pythonimplementation
# 934       networkmodeling
# 935            mcmodeling
# 936      interpretresults
# 937            mcmodeling
# 938            mcmodeling
# 939            mcmodeling
# 940            mcmodeling
# 941            mcmodeling
# 942            mcmodeling
#
# [943 rows x 16 columns]

# %%
np.random.random()
# Out:
# 0.002514846659003589

# %%
score_column = [np.random.random() for _ in range(synth_data.shape[0])]
synth_data['new column'] = score_column
synth_data.head()
# Out:
#   Student Name  Student ID Course Title Course Code Class Title  Class Code  \
# 0    Student_1        1111        CS166       CS166         NaN         NaN
# 1    Student_1        1111        CS166       CS166         NaN         NaN
# 2    Student_1        1111        CS166       CS166         NaN         NaN
# 3    Student_1        1111        CS166       CS166         NaN         NaN
# 4    Student_1        1111        CS166       CS166         NaN         NaN
#
#   Assessment Type     Assignment Title Group Assignment Poll Title  \
# 0      assignment  Elevator simulation            False        NaN
# 1      assignment  Elevator simulation            False        NaN
# 2      assignment  Elevator simulation            False        NaN
# 3      assignment  Elevator simulation            False        NaN
# 4      assignment  Elevator simulation            False        NaN
#
#          Grader Name               Updated Date                  Comment  \
# 0  Prof. Ben Affleck  2020-01-24 18:03:47+00:00  This is excellent work!
# 1  Prof. Ben Affleck  2020-01-24 18:12:14+00:00  This is excellent work!
# 2  Prof. Ben Affleck  2020-01-31 14:13:50+00:00  This is excellent work!
# 3  Prof. Ben Affleck  2020-01-31 14:27:00+00:00  This is excellent work!
# 4  Prof. Ben Affleck  2020-01-31 14:18:24+00:00  This is excellent work!
#
#    Score Learning Outcome Name               HC Name  new column
# 0    NaN                   NaN                   NaN    0.884968
# 1    NaN                   NaN                   NaN    0.074432
# 2    4.0        responsibility                   NaN    0.930623
# 3    4.0                   NaN  pythonimplementation    0.564036
# 4    NaN                   NaN                   NaN    0.175700

# %%
# replace space in header with "_"
df.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)
df.columns
# Out:
# Index(['Student_Name', 'Student_ID', 'Course_Title', 'Course_Code',
#        'Class_Title', 'Class_Code', 'Assessment_Type', 'Assignment_Title',
#        'Group_Assignment', 'Poll_Title', 'Grader_Name', 'Updated_Date',
#        'Comment', 'Score', 'Learning_Outcome_Name', 'HC_Name'],
#       dtype='object')

# %%
# change HC column to LO and vice versa, due to error in the data
df.rename(columns={'Learning_Outcome_Name':'HC','HC_Name':'LO' }, inplace=True)
df.columns
# Out:
# Index(['Student_Name', 'Student_ID', 'Course_Title', 'Course_Code',
#        'Class_Title', 'Class_Code', 'Assessment_Type', 'Assignment_Title',
#        'Group_Assignment', 'Poll_Title', 'Grader_Name', 'Updated_Date',
#        'Comment', 'Score', 'HC', 'LO'],
#       dtype='object')

# %%
# removing incomplete instances with no Score data
# data_simplified <- data_simplified[complete.cases(data_simplified$Score),]
df.dropna(subset=['Score'], inplace=True)
df.head()
# Out:
#    Student_Name  Student_ID                               Course_Title  \
# 2     Student_1      543055  Modeling, Simulation, and Decision Making
# 3     Student_1      543055  Modeling, Simulation, and Decision Making
# 5     Student_1      543055  Modeling, Simulation, and Decision Making
# 8     Student_1      543055  Modeling, Simulation, and Decision Making
# 10    Student_1      543055  Modeling, Simulation, and Decision Making
#
#    Course_Code Class_Title  Class_Code Assessment_Type     Assignment_Title  \
# 2        CS166         NaN         NaN      assignment  Elevator simulation
# 3        CS166         NaN         NaN      assignment  Elevator simulation
# 5        CS166         NaN         NaN      assignment  Elevator simulation
# 8        CS166         NaN         NaN      assignment  Elevator simulation
# 10       CS166         NaN         NaN      assignment  Elevator simulation
#
#    Group_Assignment Poll_Title        Grader_Name               Updated_Date  \
# 2             False        NaN  Raquel H. Ribeiro  2020-01-31 14:13:50+00:00
# 3             False        NaN  Raquel H. Ribeiro  2020-01-31 14:27:00+00:00
# 5             False        NaN  Raquel H. Ribeiro  2020-01-31 14:28:14+00:00
# 8             False        NaN  Raquel H. Ribeiro  2020-01-31 14:17:30+00:00
# 10            False        NaN  Raquel H. Ribeiro  2020-01-31 14:25:34+00:00
#
#                                               Comment  Score               HC  \
# 2   It looks like you all worked well together as ...    4.0   responsibility
# 3   The code runs, and you’ve provided very clearl...    4.0              NaN
# 5   There was a very clear measurement of the aver...    3.0              NaN
# 8   A well-organized and structured report, with c...    3.0  professionalism
# 10  This is a good starting point for a strong app...    3.0         critique
#
#                       LO
# 2                    NaN
# 3   pythonimplementation
# 5       interpretresults
# 8                    NaN
# 10                   NaN

# %%
## generating week numbers
# data$Week <- as.factor(round(as.numeric(as.character(data$Class_Code))))

# df['Class_Code'] = df['Class_Code'].fillna(0).astype(int)

# %%
# Generate CO column
# data$CO <- mapvalues(data$LO, c("mcanalysis", "mcmodeling", "interpretresults", "professionalism", "pythonimplementation","caanalysis", "camodeling", "networkanalysis","networkmodeling" ),
#                      c("MonteCarlo","MonteCarlo","Simulations","Simulations","Simulations","Cellular Automata","Cellular Automata","Networks","Networks"))
def map_CO(row, LO_IN_ORDER, CO_IN_ORDER):
    mapping = dict(zip(LO_IN_ORDER, CO_IN_ORDER)) 
#     print(mapping)
    if not pd.isnull(row['LO']):
        return mapping[row['LO']]
    return np.nan
df['CO'] = df.apply(lambda row: map_CO(row, LO_IN_ORDER, CO_IN_ORDER), axis=1)
df['CO'][:10]
# Out:
# 2             NaN
# 3     Simulations
# 5     Simulations
# 8             NaN
# 10            NaN
# 11            NaN
# 12    Simulations
# 13            NaN
# 19    Simulations
# 20            NaN
# Name: CO, dtype: object

# %%
# Add weight column. Current data set does not have weights for scores. 
def map_weight(row, ASSIGNMENT_TITLES, ASSIGNMENT_WEIGHTS):
    mapping = dict(zip(ASSIGNMENT_TITLES, ASSIGNMENT_WEIGHTS))
    if row['Assessment_Type'] != 'assignment':
        return 1
    else:
        return mapping[row['Assignment_Title']]
df['weight'] = df.apply(lambda row: map_weight(row, ASSIGNMENT_TITLES, ASSIGNMENT_WEIGHTS), axis=1)
# df['weight'][:20]

# %%
# Add weighted score column                                    
# data <- mutate(data, weighted_score = Score * weight)
df['weighted_score'] = df['Score'] * df['weight']
# df['weighted_score'][:10]

# %%
# drop null in LO column
df.dropna(subset=['LO'], inplace=True)
# df.head()

# %%
for k,v in enumerate([1,7,4]):
    print(k,v)
# Out:
# 0 1
# 1 7
# 2 4

# %%
# get data only for a student (student 1 for example)
list_of_students = df['Student_Name'].unique()
num_students = len(list_of_students)

def match_color(val):
    # SET COLOR TO MATCH MINERVA SCHEME
    if 0 < val and val < 2:
        color = '#C83F31'
    elif 2 <= val and val < 3:
        color = '#DB883A'
    elif 3 <= val and val < 4:
        color = '#56A371'
    elif 4 <= val and val < 5:
        color = '#3473B6'
    elif 5 <= val:
        color = '#573F88'
    return color
def set_color(row, col_name):
    return match_color(row[col_name])

def split_date_func(df):
    # truncate the Updated Date column so that it contains only the date information
    df['Updated_Date'] = df['Updated_Date'].str.slice(stop=10)

    # convert to DateTime
    df['Updated_Date']= pd.to_datetime(df['Updated_Date'])
    df = df.sort_values(by=['Updated_Date'])
    # summarize the grouped Updated_Date into new columns: 'sum_weighted' and 'tot_weights'
    df = df.groupby('Updated_Date').apply(lambda x: pd.DataFrame({'sum_weighted': x['weighted_score'].sum(), 
                                                             'tot_weights': x['weight'].sum()},
                                                            index=['Updated_Date'])).reset_index()
    df = df.drop(['level_1'], axis=1)
    ###### By this point we have a dataframe with:
      # * date
      # * total weighted scores
      # * total weights
      # What we want to do is taking the running average up to a certain date
      # For date #2, it equals: 
      # A/B where
      # A is (total weighted scores of date 1 + total weighted scores of date 2)
      # and B is (total weights of date1 + total weights of date 2)

      ## Idea: we can create 
      # * a new column (B) that is the cumsum of the vector column total weights
      # * a new column (A) that is the cumsum of the total weighted scores
      # * the quantity of interest would be A/B
    df['cumsum_tot_weights'] = df['tot_weights'].cumsum(axis=0)
    df['cumsum_sum_weighted'] = df['sum_weighted'].cumsum(axis=0)
    df['running_avg'] = df['cumsum_sum_weighted'] / df['cumsum_tot_weights']
    return df

def group_by_student(col_name_to_group_by, evolution=True):
    """
    return a list of df, each df corresponds to a student.
    - col_name_to_group_by: 'LO' or 'CO'
    """
    df_list = []
    
    for i in range(num_students):
        student_name = list_of_students[i]
        student_df = df[df['Student_Name'] == student_name]
        # group by LO or CO
        data_with_avg = student_df.groupby(col_name_to_group_by).apply(func=split_date_func)
        if not evolution: # obtain only the latest average score
            data_with_avg = data_with_avg.groupby(col_name_to_group_by).tail(1)
        data_with_avg.reset_index(inplace=True)
            
        # map LO to CO
        if col_name_to_group_by == 'LO':
            data_with_avg['CO'] = data_with_avg.apply(lambda row: map_CO(row, LO_IN_ORDER, CO_IN_ORDER), axis=1)
        # set color
        data_with_avg['color'] = data_with_avg.apply (lambda row: set_color(row, 'running_avg'), axis=1)
        df_list.append(data_with_avg)

    return df_list
    
# LO Evolution
LO_evolution_list = group_by_student('LO')
LO_evolution_data = []
for i, student_df in enumerate(LO_evolution_list):
    out = {'student_name': list_of_students[i]}
    out['series'] = []
    """
    out['series'] is of str type
    out['series'] = [{'name': 'caanalysis', 
                      'data': [[Date.UTC(2020, 0, 28), 4.0], [Date.UTC(2020, 1, 3), 3.5]], 
                      'visible': False},
                      {...}]
    """
    for LO, group_df in student_df.groupby('LO'):
        series_info = {'name': LO, 
                       'visible': LO in DEFAULT_LO_TO_DISPLAY_IN_EVOLUTION}
        series_info['data'] = []
        for index, row in group_df.iterrows():
            datetime = row['Updated_Date']
            series_info['data'].append(['Date.UTC',(datetime.year, datetime.month-1, datetime.day), row['running_avg']])
        out['series'].append(series_info)
    out['series'] = str(out['series']).replace("'Date.UTC', ", "Date.UTC").replace("False", "false").replace("True", "true")
    LO_evolution_data.append(out)
    
# LO average
def get_average_data(category_col, average_list, data_col='running_avg', color_col='color'):
#     average_list = group_by_student(col_name_to_group_by, evolution=False)
    average_data = []
    for i, student_df in enumerate(average_list):
        out = {'student_name': list_of_students[i],
                'categories': list(student_df[category_col]),
               'mean_of_avg': [np.mean(student_df[data_col])]*student_df.shape[0]}
        """
        out['avg'] = [{'y': 3.5, 'color': '#56A371'},
                      {...},
                      ...]
        """
        out['data'] = []
        for index, row in student_df.iterrows():
            if color_col is None:
                color = 'black'
            else:
                color = row[color_col]

            out['data'].append({'y': row[data_col],
                               'color': color})
        average_data.append(out)
    return average_data
LO_average_df_list = group_by_student(col_name_to_group_by='LO', evolution=False)
LO_average_data = get_average_data('LO', LO_average_df_list)
# LO mean and range for whole class 
def get_summary_stat_data(df_list, val_col):
    summary_stat_data = {'LO': [LO for LO in df['LO'].unique()],
                         'mean': [],
                         'range': []}
    for i, student_df in enumerate(df_list):
        student_df = student_df[['LO', val_col]]
        if i == 0:
            merged_df = student_df
        else:
            merged_df = merged_df.merge(student_df, on='LO')
    merged_df['mean'] = merged_df.loc[:, merged_df.columns != 'LO'].mean(axis=1)
    merged_df['min'] = merged_df.loc[:, merged_df.columns != 'LO'].min(axis=1)
    merged_df['max'] = merged_df.loc[:, merged_df.columns != 'LO'].max(axis=1)
    merged_df['range'] = merged_df.apply(lambda x: [x['min'], x['max']], axis=1)
    summary_stat_data = {'LO': list(merged_df['LO']),
                         'mean': list(merged_df['mean']),
                         'range': list(merged_df['range'])}
    return summary_stat_data
LO_summary_stat_data = get_summary_stat_data(df_list=LO_average_df_list,
                                             val_col='running_avg')

# CO average
CO_average_df_list = group_by_student(col_name_to_group_by='CO', evolution=False)
CO_average_data = get_average_data('CO', CO_average_df_list)


# LO contribution
## for indvidual student 
contrib_df_list = []
for i, m in enumerate(zip(LO_average_df_list, CO_average_df_list)):
    # lookup CO table from LO table
    LO_df, CO_df = m
    num_CO = CO_df.shape[0]
    contrib_df = LO_df.merge(CO_df, on="CO")
    contrib_df['LO_contrib'] = contrib_df['cumsum_sum_weighted_x']/contrib_df['cumsum_tot_weights_y']/num_CO/np.mean(CO_df['running_avg'])
    contrib_df = contrib_df[['LO', 'LO_contrib']]
    contrib_df_list.append(contrib_df)
# print(contrib_df_list[0])
LO_contrib_data = get_average_data('LO', contrib_df_list, data_col='LO_contrib', color_col=None)


## summary stats for whole class
contrib_summary_stat_data = get_summary_stat_data(df_list=contrib_df_list,
                                             val_col='LO_contrib')

print(contrib_summary_stat_data)


# lo_evolution_data = []
# intermediate_whole_class_lo_data = {LO: [] for LO in df['LO'].unique()}
# LO_avg_data = []


    
# for i in range(num_students):
#     student_name = list_of_students[i]
#     student_df = df[df['Student_Name'] == student_name]
#     # group by LO
#     col_name_to_group_by = 'LO'

#     data_with_avg_LO = student_df.groupby(col_name_to_group_by).apply(func=split_date_func)
#     # map LO to CO
#     data_with_avg_LO.reset_index(inplace=True)
#     data_with_avg_LO['CO'] = data_with_avg_LO.apply(lambda row: map_CO(row, LO_IN_ORDER, CO_IN_ORDER), axis=1)
#     agg = {LO: {'visible': False, 'content': []} for LO in data_with_avg_LO['LO'].unique()}
#     for index, row in data_with_avg_LO.iterrows():
#         time_info = (row['Updated_Date'].year, row['Updated_Date'].month-1, row['Updated_Date'].day)
#         if row['LO'] in DEFAULT_LO_TO_DISPLAY_IN_EVOLUTION:
#             visible = True
#         else:
#             visible = False
#         agg[row['LO']]['visible'] = visible
#         agg[row['LO']]['content'].append(['mark',time_info, row['running_avg']])
        
#     series = []    
#     for k, v in agg.items():
#         series.append({'name':k, 
#                        'data': v['content'],
#                        'visible': v['visible']})
#         intermediate_whole_class_lo_data[k].append(v['content'][-1][-1])
#     LO_avg_this_student = {}
#     LO_avg_this_student['student_name'] = student_name
#     LO_avg_this_student['LO'] = []
#     LO_avg_this_student['LO_avg'] = []
#     LO_avg_this_student['color'] = []
#     for LO in series:
#         LO_avg_this_student['LO'].append(LO['name'])
        
#         # SET COLOR TO MATCH MINERVA SCHEME
#         color = match_color(LO['data'][-1][-1])
#         LO_avg_this_student['LO_avg'].append({'y': LO['data'][-1][-1],
#                                               'color': color})
# #         LO_avg_this_student['color'].append(color)
            
            
#     LO_avg_data.append(LO_avg_this_student)

#     series = str(series).replace("'mark', ", "Date.UTC")
# #     print('SERIES: ', series)
#     series = series.replace("True", 'true')
#     series = series.replace("False", 'false')
#     # add this student's data to data for plotting LO evolution
#     lo_evolution_data.append({'student_name': student_name, 'series': series})
    
    
# # print(lo_evolution_data)
# # compute summary stats for LO averages for the whole class
# whole_class_lo_data = {'LO': [], 'mean': [], 'range':[]} 
# # print(len(intermediate_whole_class_lo_data['pythonimplementation']))
# for k, v in intermediate_whole_class_lo_data.items():
#     whole_class_lo_data['LO'].append(k)
#     # compute mean
#     mean = np.mean(v)
#     whole_class_lo_data['mean'].append(mean)
#     # compute range
#     min_val = np.min(v)
#     max_val = np.max(v)
#     whole_class_lo_data['range'].append([min_val, max_val])

# # whole_class_lo_data
# print('-'*10)
# print(whole_class_lo_data)
# # {'student_name': 'Student_1', 'series': ["{'name': 'caanalysis',
# Out:
# {'LO': ['caanalysis', 'camodeling', 'interpretresults', 'professionalism', 'pythonimplementation', 'mcmodeling', 'networkanalysis', 'networkmodeling'], 'mean': [0.040325725067751485, 0.22217404846150074, 0.09831663081556484, 0.04752736851241704, 0.10099188105863678, 0.25116397898041704, 0.10324876170098797, 0.13625160540272405], 'range': [[0.01781200933710316, 0.050271878526726176], [0.16353247389811584, 0.2582741353879958], [0.08464142813173284, 0.1071022540318646], [0.03918522585742792, 0.05642761875448857], [0.08865287511537275, 0.11749275317496688], [0.23165094974645645, 0.2968668222850527], [0.06449175794468386, 0.1231609230157839], [0.11630004053707488, 0.15799733251256798]]}

# %%
LO_evolution_data
# Out:
# [{'series': "[{'name': 'caanalysis', 'visible': false, 'data': [[Date.UTC(2020, 0, 28), 4.0], [Date.UTC(2020, 1, 3), 3
 'visible': false, 'data': [[Date.UTC(2020, 0, 31), 3.0], [Date.UTC(2020, 1, 25), 2.6666666666666665], [Date.UTC(2020, 2, 5), 2.933333333333333], [Date.UTC(2020, 2, 6), 2.9375], [Date.UTC(2020, 2, 19), 3.0], [Date.UTC(2020, 2, 26), 3.206896551724138]]}, {'name': 'mcmodeling', 'visible': false, 'data': [[Date.UTC(2020, 2, 17), 4.0], [Date.UTC(2020, 3, 1), 3.5], [Date.UTC(2020, 3, 3), 3.0], [Date.UTC(2020, 3, 7), 3.25], [Date.UTC(2020, 3, 10), 3.0], [Date.UTC(2020, 3, 17), 3.0], [Date.UTC(2020, 3, 22), 3.142857142857143]]}, {'name': 'networkanalysis', 'visible': true, 'data': [[Date.UTC(2020, 2, 4), 3.0], [Date.UTC(2020, 2, 26), 3.0]]}, {'name': 'networkmodeling', 'visible': true, 'data': [[Date.UTC(2020, 1, 13), 4.0], [Date.UTC(2020, 1, 26), 3.5], [Date.UTC(2020, 1, 27), 3.3333333333333335], [Date.UTC(2020, 2, 12), 3.5], [Date.UTC(2020, 2, 26), 3.8], [Date.UTC(2020, 3, 3), 3.5]]}, {'name': 'professionalism', 'visible': false, 'data': [[Date.UTC(2020, 0, 31), 4.0], [Date.UTC(2020, 2, 5), 2.5], [Date.UTC(2020, 2, 26), 2.7142857142857144]]}, {'name': 'pythonimplementation', 'visible': false, 'data': [[Date.UTC(2020, 0, 24), 2.0], [Date.UTC(2020, 0, 31), 3.3333333333333335], [Date.UTC(2020, 2, 5), 3.066666666666667], [Date.UTC(2020, 2, 10), 3.0625], [Date.UTC(2020, 2, 26), 3.3181818181818183], [Date.UTC(2020, 3, 18), 3.4642857142857144]]}]",
#   'student_name': 'Student_11'}]

# %%
# CO data
CO_avg_data = []
for i in range(num_students):
    student_name = list_of_students[i]
    student_df = df[df['Student_Name'] == student_name]
    # group by CO
    col_name_to_group_by = 'CO'

    data_CO_evolution = student_df.groupby(col_name_to_group_by).apply(func=split_date_func)
    data_CO_avg = data_CO_evolution.groupby(col_name_to_group_by).tail(1)
    data_CO_avg.reset_index(inplace=True)
#     data_with_avg_CO.reset_index(inplace=True)
#     data_with_avg_LO['CO'] = data_with_avg_LO.apply(lambda row: map_CO(row, LO_IN_ORDER, CO_IN_ORDER), axis=1)
# data_with_avg_CO.head()
    
    CO_avg_this_student = {}
    CO_avg_this_student['student_name'] = student_name
    CO_avg_this_student['CO'] = []
    CO_avg_this_student['CO_avg'] = []
    CO_avg_this_student['color'] = []
    CO_avg_this_student['course_avg'] = [np.mean(data_CO_avg['running_avg'])]*data_CO_avg.shape[0]
    for index, row in data_CO_avg.iterrows():
        CO_avg_this_student['CO'].append(row['CO'])
        # SET COLOR TO MATCH MINERVA SCHEME
        color = match_color(row['running_avg'])
        CO_avg_this_student['CO_avg'].append({'y': row['running_avg'],
                                              'color': color})
    CO_avg_data.append(CO_avg_this_student)
print(CO_avg_data[0])
# Out:
# {'student_name': 'Student_1', 'CO': ['Cellular Automata', 'MonteCarlo', 'Networks', 'Simulations'], 'CO_avg': [{'y': 3.3636363636363638, 'color': '#56A371'}, {'y': 3.3333333333333335, 'color': '#56A371'}, {'y': 3.5357142857142856, 'color': '#56A371'}, {'y': 3.236111111111111, 'color': '#56A371'}], 'color': [], 'course_avg': [3.3671987734487736, 3.3671987734487736, 3.3671987734487736, 3.3671987734487736]}

# %%
# LO contribution
intermediate_data_whole_class_LO_contrib = {LO: [] for LO in df['LO'].unique()}
LO_contrib_data = []
# print(intermediate_data_whole_class_LO_contrib)
for i in range(num_students):
    student_name = list_of_students[i]
    student_df = df[df['Student_Name'] == student_name]
    # group by CO
    col_name_to_group_by = 'CO'
    data_with_avg_CO = student_df.groupby(col_name_to_group_by).apply(func=split_date_func)
    data_with_avg_CO = data_with_avg_CO.groupby(col_name_to_group_by).tail(1)
    data_with_avg_CO.reset_index(inplace=True)
    num_CO = data_with_avg_CO.shape[0]
    
    # group by LO
    col_name_to_group_by = 'LO'
    data_with_avg_LO = student_df.groupby(col_name_to_group_by).apply(func=split_date_func)
    data_with_avg_LO = data_with_avg_LO.groupby(col_name_to_group_by).tail(1)
    data_with_avg_LO.reset_index(inplace=True)
    # map LO to CO
    data_with_avg_LO['CO'] = data_with_avg_LO.apply(lambda row: map_CO(row, LO_IN_ORDER, CO_IN_ORDER), axis=1)

    # lookup CO table from LO table
    data_with_avg_LO = data_with_avg_LO.merge(data_with_avg_CO, on="CO")
    data_with_avg_LO['LO_contrib'] = data_with_avg_LO['cumsum_sum_weighted_x']/data_with_avg_LO['cumsum_tot_weights_y']/num_CO/np.mean(data_with_avg_CO['running_avg'])
    for k,v in data_with_avg_LO.iterrows():
        intermediate_data_whole_class_LO_contrib[v['LO']].append(v['LO_contrib'])
    
    LO_contrib_data_this_student = {}
    LO_contrib_data_this_student['LO'] = list(data_with_avg_LO['LO'])
    LO_contrib_data_this_student['LO_avg'] = list(data_with_avg_LO['LO_contrib'])
    LO_contrib_data_this_student['student_name'] = student_name
    LO_contrib_data.append(LO_contrib_data_this_student)
        
# compute summary stats for LO averages for the whole class
whole_class_lo_contrib_data = {'LO': [], 'mean': [], 'range':[]} 
for k, v in intermediate_data_whole_class_LO_contrib.items():
    whole_class_lo_contrib_data['LO'].append(k)
    # compute mean
    mean = np.mean(v)
    whole_class_lo_contrib_data['mean'].append(mean)
    # compute range
    min_val = np.min(v)
    max_val = np.max(v)
    whole_class_lo_contrib_data['range'].append([min_val, max_val])
LO_contrib_data
# Out:
# [{'LO': ['caanalysis',
#    'camodeling',
#    'interpretresults',
#    'professionalism',
#    'pythonimplementation',
#    'mcmodeling',
#    'networkanalysis',
#    'networkmodeling'],
#   'LO_avg': [0.04724725797163557,
#    0.20248824844986674,
#    0.10311901541428399,
#    0.03918522585742792,
#    0.09796306464356978,
#    0.24748563699428158,
#    0.1193234321222429,
#    0.14318811854669147],
#   'student_name': 'Student_1'},
#  {'LO': ['caanalysis',
#    'camodeling',
#    'interpretresults',
#    'professionalism',
#    'pythonimplementation',
#    'mcmodeling',
#    'networkanalysis',
#    'networkmodeling'],
#   'LO_avg': [0.01781200933710316,
#    0.2582741353879958,
#    0.0940775141044181,
#    0.05268340789847414,
#    0.09909498152332041,
#    0.2968668222850527,
#    0.06449175794468386,
#    0.11669937151895174],
#   'student_name': 'Student_2'},
#  {'LO': ['caanalysis',
#    'camodeling',
#    'interpretresults',
#    'professionalism',
#    'pythonimplementation',
#    'mcmodeling',
#    'networkanalysis',
#    'networkmodeling'],
#   'LO_avg': [0.04816466325272798,
#    0.24770398244260106,
#    0.09700770204422679,
#    0.05330093518913559,
#    0.08954557111774779,
#    0.26490564789000387,
#    0.08307145752648207,
#    0.11630004053707488],
#   'student_name': 'Student_3'},
#  {'LO': ['caanalysis',
#    'camodeling',
#    'interpretresults',
#    'professionalism',
#    'pythonimplementation',
#    'mcmodeling',
#    'networkanalysis',
#    'networkmodeling'],
#   'LO_avg': [0.03790651904942014,
#    0.2274391142965209,
#    0.10281494207924916,
#    0.04759951022187461,
#    0.09519902044374921,
#    0.23165094974645645,
#    0.11325157543160093,
#    0.14413836873112845],
#   'student_name': 'Student_4'},
#  {'LO': ['caanalysis',
#    'camodeling',
#    'interpretresults',
#    'professionalism',
#    'pythonimplementation',
#    'mcmodeling',
#    'networkanalysis',
#    'networkmodeling'],
#   'LO_avg': [0.02884640305483322,
#    0.23077122443866577,
#    0.10256498863940701,
#    0.04578794135687813,
#    0.09523891802230651,
#    0.24176033036431652,
#    0.1231609230157839,
#    0.13186927110780902],
#   'student_name': 'Student_5'},
#  {'LO': ['caanalysis',
#    'camodeling',
#    'interpretresults',
#    'professionalism',
#    'pythonimplementation',
#    'mcmodeling',
#    'networkanalysis',
#    'networkmodeling'],
#   'LO_avg': [0.050271878526726176,
#    0.20826921103929413,
#    0.08464142813173284,
#    0.05642761875448857,
#    0.10946958038370781,
#    0.24828152251974966,
#    0.08464142813173284,
#    0.15799733251256798],
#   'student_name': 'Student_6'},
#  {'LO': ['caanalysis',
#    'camodeling',
#    'interpretresults',
#    'professionalism',
#    'pythonimplementation',
#    'mcmodeling',
#    'networkanalysis',
#    'networkmodeling'],
#   'LO_avg': [0.02942792043356607,
#    0.2427803435769201,
#    0.10050160326641985,
#    0.04168955394755193,
#    0.09901269062543584,
#    0.23763045750104603,
#    0.11680941058889552,
#    0.13214802006016463],
#   'student_name': 'Student_7'},
#  {'LO': ['caanalysis',
#    'camodeling',
#    'interpretresults',
#    'professionalism',
#    'pythonimplementation',
#    'mcmodeling',
#    'networkanalysis',
#    'networkmodeling'],
#   'LO_avg': [0.04223542411147318,
#    0.21721075257329064,
#    0.09596736328031648,
#    0.04305077978930085,
#    0.11749275317496688,
#    0.2322948326131025,
#    0.11900819010720522,
#    0.13273990435034427],
#   'student_name': 'Student_8'},
#  {'LO': ['caanalysis',
#    'camodeling',
#    'interpretresults',
#    'professionalism',
#    'pythonimplementation',
#    'mcmodeling',
#    'networkanalysis',
#    'networkmodeling'],
#   'LO_avg': [0.04463641264550237,
#    0.22955869360544076,
#    0.09157549737192351,
#    0.0487103709425125,
#    0.08865287511537275,
#    0.25051047913292146,
#    0.10778060614401791,
#    0.13857506504230874],
#   'student_name': 'Student_9'},
#  {'LO': ['caanalysis',
#    'camodeling',
#    'interpretresults',
#    'professionalism',
#    'pythonimplementation',
#    'mcmodeling',
#    'networkanalysis',
#    'networkmodeling'],
#   'LO_avg': [0.047974745192843685,
#    0.2158863533677966,
#    0.10211063060737106,
#    0.050603498354095396,
#    0.10753243400245271,
#    0.2544374878977603,
#    0.0942361066288001,
#    0.12721874394888014],
#   'student_name': 'Student_10'},
#  {'LO': ['caanalysis',
#    'camodeling',
#    'interpretresults',
#    'professionalism',
#    'pythonimplementation',
#    'mcmodeling',
#    'networkanalysis',
#    'networkmodeling'],
#   'LO_avg': [0.049059742169434754,
#    0.16353247389811584,
#    0.1071022540318646,
#    0.0437622113248479,
#    0.11170880259237491,
#    0.2569796018398963,
#    0.10996149106942273,
#    0.1578934230740429],
#   'student_name': 'Student_11'}]

# %%
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score
import nltk
import csv
import time
import numpy as np
import cvxpy as cvx
from selenium import webdriver
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /Users/admin/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/admin/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, NoSuchWindowException

# URL to the first page of audience reviews for The Godfather
URL = 'https://forum.minerva.kgi.edu/app/'
# create a Chrome webdriver 
driver = webdriver.Chrome('/Users/admin/Downloads/chromedriver-2')  # Optional argument, if not specified will search path.
# driver.implicitly_wait(1)
driver.get(URL);

# %%
    
import time
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, NoSuchWindowException

# URL to the first page of audience reviews for The Godfather
URL = 'https://www.rottentomatoes.com/m/godfather/reviews?type=user'
# create a Chrome webdriver 
driver = webdriver.Chrome('/Users/admin/Downloads/chromedriver')  # Optional argument, if not specified will search path.
# driver.implicitly_wait(1)
first_review_prev_batch = ''
num_reviews = 0            
def store_data():
    global num_reviews 
    global first_review_prev_batch
    reviews = []
    rates = []
    while True:
        try:
            all_reviews = driver.find_elements_by_class_name('audience-reviews__item')
            end = len(all_reviews)
            i = 0
            for element in all_reviews:
                i += 1
                p_elem = element.find_element_by_xpath(".//p[@class='audience-reviews__review js-review-text clamp clamp-8 js-clamp']")
                review = p_elem.text
                if review == first_review_prev_batch:
                    break
                reviews.append(review)
                # get the number of stars (full or half)
                star_elem = element.find_elements_by_css_selector(".star-display__filled")
                # if there are more than 3 full stars (rate >= 3.5), then the review is positive
                if len(star_elem) > 3:
                    rate = 'positive'
                else:
                    rate = 'negative'
                rates.append(rate)
            if i == end:
                break
        # StaleElementsReferenceException occurs when my internet connection was slow, and 
        # therefore the web navigates after the data is scraped, causing insconsitencies.
        # Therefore, this exception needs to be caught.
        except StaleElementReferenceException:
            reviews = []
            rates = []
            pass
            
    # write to csv file:
    for i in range(len(reviews)):
        if i==0:
            first_review_prev_batch = reviews[i]
        with open('rottentomato.csv', mode='a') as file:
            writer = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
            writer.writerow([reviews[i], rates[i]])
    num_reviews += len(reviews)
            

with open('rottentomato.csv', mode='w') as file:
            writer = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
            writer.writerow(['text', 'label'])
driver.get(URL);
store_data()

while True:
    if num_reviews >= 20:
        break
    try:
        driver.find_element_by_class_name('js-prev-next-paging-next').click()
        time.sleep(1)
    except:
        break
    store_data()
driver.quit()
# Out:
#   File "<ipython-input-85-11bf82b4b368>", line 14
#     global num_reviews
#          ^
# IndentationError: expected an indented block

# %%
# CO data
for i in range(num_students):
    student_name = list_of_students[i]
    student_df = df[df['Student_Name'] == student_name]
    # group by CO
    col_name_to_group_by = 'CO'

    data_with_avg_CO = student_df.groupby(col_name_to_group_by).apply(func=split_date_func)
    data_with_avg_CO.reset_index(inplace=True)
#     data_with_avg_LO['CO'] = data_with_avg_LO.apply(lambda row: map_CO(row, LO_IN_ORDER, CO_IN_ORDER), axis=1)
    print(data_with_avg_CO)
    agg = {LO: {'visible': False, 'content': []} for LO in data_with_avg_LO['LO'].unique()}
    for index, row in data_with_avg_LO.iterrows():
        time_info = (row['Updated_Date'].year, row['Updated_Date'].month-1, row['Updated_Date'].day)
        if row['LO'] in DEFAULT_LO_TO_DISPLAY_IN_EVOLUTION:
            visible = True
        else:
            visible = False
        agg[row['LO']]['visible'] = visible
        agg[row['LO']]['content'].append(['mark',time_info, row['running_avg']])
        
    series = []    
    for k, v in agg.items():
        series.append({'name':k, 
                       'data': v['content'],
                       'visible': v['visible']})
        intermediate_whole_class_lo_data[k].append(v['content'][-1][-1])
    LO_avg_this_student = {}
    LO_avg_this_student['student_name'] = student_name
    LO_avg_this_student['LO'] = []
    LO_avg_this_student['LO_avg'] = []
    LO_avg_this_student['color'] = []
    for LO in series:
        LO_avg_this_student['LO'].append(LO['name'])
        
        # SET COLOR TO MATCH MINERVA SCHEME
        if 0 < LO['data'][-1][-1] and LO['data'][-1][-1] < 2:
            color = '#C83F31'
        elif 2 <= LO['data'][-1][-1] and LO['data'][-1][-1] < 3:
            color = '#DB883A'
        elif 3 <= LO['data'][-1][-1] and LO['data'][-1][-1] < 4:
            color = '#56A371'
        elif 4 <= LO['data'][-1][-1] and LO['data'][-1][-1] < 5:
            color = '#3473B6'
        elif 5 <= LO['data'][-1][-1]:
            color = '#573F88'
        LO_avg_this_student['LO_avg'].append({'y': LO['data'][-1][-1],
                                              'color': color})
#         LO_avg_this_student['color'].append(color)
            
            
    LO_avg_data.append(LO_avg_this_student)

    series = str(series).replace("'mark', ", "Date.UTC")
    series = series.replace("True", 'true')
    series = series.replace("False", 'false')
    # add this student's data to data for plotting LO evolution
    lo_evolution_data.append({'student_name': student_name, 'series': series})
# Out:
#                    CO  level_1 Updated_Date  sum_weighted  tot_weights  \
# 0   Cellular Automata        0   2020-01-22           4.0            1
# 1   Cellular Automata        1   2020-01-28           4.0            1
# 2   Cellular Automata        2   2020-02-03
#                    CO  level_1 Updated_Date  sum_weighted  tot_weights  \
# 0   Cellular Automata        0   2020-01-22           4.0            1
# 1   Cellular Automata        1   2020-01-28           4.0            1
# 2   Cellular Automata        2   2020-02-03           2.0            1
# 3   Cellular Automata        3   2020-02-06           4.0            1
# 4   Cellular Automata        4   2020-03-05          12.0            6
# 5          MonteCarlo        0   2020-03-17           4.0            1
# 6          MonteCarlo        1   2020-04-01           3.0            1
# 7          MonteCarlo        2   2020-04-03           2.0            1
# 8          MonteCarlo        3   2020-04-07           4.0            1
# 9          MonteCarlo        4   2020-04-10           2.0            1
# 10         MonteCarlo        5   2020-04-17           3.0            1
# 11         MonteCarlo        6   2020-04-22           4.0            1
# 12           Networks        0   2020-02-13           4.0            1
# 13           Networks        1   2020-02-26           3.0            1
# 14           Networks        2   2020-02-27           3.0            1
# 15           Networks        3   2020-03-04           3.0            1
# 16           Networks        4   2020-03-12           4.0            1
# 17           Networks        5   2020-03-26          60.0           18
# 18           Networks        6   2020-04-03          18.0            6
# 19        Simulations        0   2020-01-24           2.0            1
# 20        Simulations        1   2020-01-31          22.0            6
# 21        Simulations        2   2020-02-25           2.0            1
# 22        Simulations        3   2020-03-05          84.0           30
# 23        Simulations        4   2020-03-06           3.0            1
# 24        Simulations        5   2020-03-10           3.0            1
# 25        Simulations        6   2020-03-19           4.0            1
# 26        Simulations        7   2020-03-26          84.0           24
# 27        Simulations        8   2020-04-18          24.0            6
#
#     cumsum_tot_weights  cumsum_sum_weighted  running_avg
# 0                    1                  4.0     4.000000
# 1                    2                  8.0     4.000000
# 2                    3                 10.0     3.333333
# 3                    4                 14.0     3.500000
# 4                   10                 26.0     2.600000
# 5                    1                  4.0     4.000000
# 6                    2                  7.0     3.500000
# 7                    3                  9.0     3.000000
# 8                    4                 13.0     3.250000
# 9                    5                 15.0     3.000000
# 10                   6                 18.0     3.000000
# 11                   7                 22.0     3.142857
# 12                   1                  4.0     4.000000
# 13                   2                  7.0     3.500000
# 14                   3                 10.0     3.333333
# 15                   4                 13.0     3.250000
# 16                   5                 17.0     3.400000
# 17                  23                 77.0     3.347826
# 18                  29                 95.0     3.275862
# 19                   1                  2.0     2.000000
# 20                   7                 24.0     3.428571
# 21                   8                 26.0     3.250000
# 22                  38                110.0     2.894737
# 23                  39                113.0     2.897436
# 24                  40                116.0     2.900000
# 25                  41                120.0     2.926829
# 26                  65                204.0     3.138462
# 27                  71                228.0     3.211268

# %%
# group by LO
col_name_to_group_by = 'LO'
def split_date_func(df):
    # truncate the Updated Date column so that it contains only the date information
    df['Updated_Date'] = df['Updated_Date'].str.slice(stop=10)
    
    # convert to DateTime
    df['Updated_Date']= pd.to_datetime(df['Updated_Date'])
#     print(df[['Updated_Date','LO']])
    df = df.sort_values(by=['Updated_Date'])
#     print(df[['Updated_Date','LO']])
    print('-'*10)
#     print(df['Updated_Date'])
    # summarize the grouped Updated_Date into new columns: 'sum_weighted' and 'tot_weights'
    df = df.groupby('Updated_Date').apply(lambda x: pd.DataFrame({'sum_weighted': x['weighted_score'].sum(), 
                                                             'tot_weights': x['weight'].sum()},
                                                            index=['Updated_Date'])).reset_index()
    df = df.drop(['level_1'], axis=1)
#     print(df)
    ###### By this point we have a dataframe with:
      # * date
      # * total weighted scores
      # * total weights
      # What we want to do is taking the running average up to a certain date
      # For date #2, it equals: 
      # A/B where
      # A is (total weighted scores of date 1 + total weighted scores of date 2)
      # and B is (total weights of date1 + total weights of date 2)

      ## Idea: we can create 
      # * a new column (B) that is the cumsum of the vector column total weights
      # * a new column (A) that is the cumsum of the total weighted scores
      # * the quantity of interest would be A/B
    df['B'] = df['tot_weights'].cumsum(axis=0)
    df['A'] = df['sum_weighted'].cumsum(axis=0)
    df['running_avg'] = df['A'] / df['B']
    print(df)
    return df
    
data_with_avg_LO = student_df.groupby(col_name_to_group_by).apply(func=split_date_func)
# map LO to CO
data_with_avg_LO.reset_index(inplace=True)
data_with_avg_LO['CO'] = data_with_avg_LO.apply(lambda row: map_CO(row, LO_IN_ORDER, CO_IN_ORDER), axis=1)
data_with_avg_LO
# Out:
# ----------
#   Updated_Date  sum_weighted  tot_weights  B    A  running_avg
# 0   2020-01-28           4.0            1  1  4.0          4.0
# 1   2020-02-03           3.0            1  2  7.0          3.5
# ----------
#   Updated_Date  sum_weighted  tot_weights  B    A  running_avg
# 0   2020-01-28           4.0            1  1  4.0          4.0
# 1   2020-02-03           3.0            1  2  7.0          3.5
# ----------
#   Updated_Date  sum_weighted  tot_weights  B    A  running_avg
# 0   2020-01-28           4.0            1  1  4.0          4.0
# 1   2020-02-03           3.0            1  2  7.0          3.5
# ----------
#   Updated_Date  sum_weighted  tot_weights  B     A  running_avg
# 0   2020-01-22           4.0            1  1   4.0     4.000000
# 1   2020-02-06           8.0            2  3  12.0     4.000000
# 2   2020-03-02          18.0            6  9  30.0     3.333333
# ----------
#   Updated_Date  sum_weighted  tot_weights   B      A  running_avg
# 0   2020-01-31           6.0            2   2    6.0     3.000000
# 1   2020-02-25           2.0            1   3    8.0     2.666667
# 2   2020-03-02          42.0           12  15   50.0     3.333333
# 3   2020-03-06           4.0            1  16   54.0     3.375000
# 4   2020-03-19           4.0            1  17   58.0     3.411765
# 5   2020-04-03          42.0           12  29  100.0     3.448276
# ----------
#   Updated_Date  sum_weighted  tot_weights  B     A  running_avg
# 0   2020-03-17           4.0            1  1   4.0     4.000000
# 1   2020-04-01           3.0            1  2   7.0     3.500000
# 2   2020-04-03           2.0            1  3   9.0     3.000000
# 3   2020-04-07           4.0            1  4  13.0     3.250000
# 4   2020-04-10           3.0            1  5  16.0     3.200000
# 5   2020-04-22           4.0            1  6  20.0     3.333333
# ----------
#   Updated_Date  sum_weighted  tot_weights   B     A  running_avg
# 0   2020-03-04           3.0            1   1   3.0     3.000000
# 1   2020-04-03          18.0            6   7  21.0     3.000000
# 2   2020-04-18          24.0            6  13  45.0     3.461538
# ----------
#   Updated_Date  sum_weighted  tot_weights   B     A  running_avg
# 0   2020-02-13           4.0            1   1   4.0          4.0
# 2     4.0     4.000000  Cellular Automata
# 3    12.0     4.000000  Cellular Automata
# 4    30.0     3.333333  Cellular Automata
# 5     6.0     3.000000        Simulations
# 6     8.0     2.666667        Simulations
# 7    50.0     3.333333        Simulations
# 8    54.0     3.375000        Simulations
# 9    58.0     3.411765        Simulations
# 10  100.0     3.448276        Simulations
# 11    4.0     4.000000         MonteCarlo
# 12    7.0     3.500000         MonteCarlo
# 13    9.0     3.000000         MonteCarlo
# 14   13.0     3.250000         MonteCarlo
# 15   16.0     3.200000         MonteCarlo
# 16   20.0     3.333333         MonteCarlo
# 17    3.0     3.000000           Networks
# 18   21.0     3.000000           Networks
# 19   45.0     3.461538           Networks
# 20    4.0     4.000000           Networks
# 21    8.0     4.000000           Networks
# 22   12.0     4.000000           Networks
# 23   36.0     4.000000           Networks
# 24   54.0     3.600000           Networks
# 25    8.0     4.000000        Simulations
# 26   26.0     3.250000        Simulations
# 27   38.0     2.714286        Simulations
# 28    3.0     3.000000        Simulations
# 29    6.0     3.000000        Simulations
# 30   14.0     3.500000        Simulations
# 31   50.0     3.125000        Simulations
# 32   53.0     3.117647        Simulations
# 33   77.0     3.347826        Simulations
# 34   95.0     3.275862        Simulations

# %%
import json
from pytz import utc 
import datetime
from dateutil.tz import tzutc
# def convert_timestamp(item_date_object):
#     if isinstance(item_date_object, (datetime.date, datetime.datetime)):
#         return item_date_object.timestamp()
# subclass JSONEncoder
# subclass JSONEncoder
class DateTimeEncoder(JSONEncoder):
        #Override the default method
        def default(self, obj):
            if isinstance(obj, (datetime.date, datetime.datetime)):
                return obj.isoformat()

agg = {LO: {'visible': False, 'content': []} for LO in data_with_avg_LO['LO'].unique()}
for index, row in data_with_avg_LO.iterrows():
    time_info = (row['Updated_Date'].year, row['Updated_Date'].month-1, row['Updated_Date'].day)
    if row['LO'] in DEFAULT_LO_TO_DISPLAY_IN_EVOLUTION:
        visible = True
    else:
        visible = False
    agg[row['LO']]['visible'] = visible
    agg[row['LO']]['content'].append(['mark',time_info, row['running_avg']])
series = []    
for k, v in agg.items():
    series.append({'name':k, 
                   'data': v['content'],
                   'visible': v['visible']})
print(str(series).replace("'mark', ", "Date.UTC"))
# json.dumps(series)
# print(type(json.dumps(series, indent=4, cls=DateTimeEncoder)))
# .strftime("Date.UTC(%Y, %m, %d)")
# .replace(tzinfo=utc).timestamp()
# Out:
# [{'name': 'caanalysis', 'data': [[Date.UTC(2020, 0, 28), 4.0], [Date.UTC(2020, 1, 3), 3.5]], 'visible': False}, {'name': 'camodeling', 'data': [[Date.UTC(2020, 0, 22), 4.0], [Date.UTC(2020, 1, 6), 4.0], [Date.UTC(2020, 2, 2), 3.3333333333333335]], 'visible': False}, {'name': 'interpretresults', 'data': [[Date.UTC(2020, 0, 31), 3.0], [Date.UTC(2020, 1, 25), 2.6666666666666665], [Date.UTC(2020, 2, 2), 3.3333333333333335], [Date.UTC(2020, 2, 6), 3.375], [Date.UTC(2020, 2, 19), 3.411764705882353], [Date.UTC(2020, 3, 3), 3.4482758620689653]], 'visible': False}, {'name': 'mcmodeling', 'data': [[Date.UTC(2020, 2, 17), 4.0], [Date.UTC(2020, 3, 1), 3.5], [Date.UTC(2020, 3, 3), 3.0], [Date.UTC(2020, 3, 7), 3.25], [Date.UTC(2020, 3, 10), 3.2], [Date.UTC(2020, 3, 22), 3.3333333333333335]], 'visible': False}, {'name': 'networkanalysis', 'data': [[Date.UTC(2020, 2, 4), 3.0], [Date.UTC(2020, 3, 3), 3.0], [Date.UTC(2020, 3, 18), 3.4615384615384617]], 'visible': True}, {'name': 'networkmodeling', 'data': [[Date.UTC(2020, 1, 13), 4.0], [Date.UTC(2020, 1, 27), 4.0], [Date.UTC(2020, 2, 12), 4.0], [Date.UTC(2020, 3, 3), 4.0], [Date.UTC(2020, 3, 18), 3.6]], 'visible': True}, {'name': 'professionalism', 'data': [[Date.UTC(2020, 0, 31), 4.0], [Date.UTC(2020, 2, 5), 3.25], [Date.UTC(2020, 3, 3), 2.7142857142857144]], 'visible': False}, {'name': 'pythonimplementation', 'data': [[Date.UTC(2020, 0, 14), 3.0], [Date.UTC(2020, 0, 24), 3.0], [Date.UTC(2020, 0, 31), 3.5], [Date.UTC(2020, 2, 6), 3.125], [Date.UTC(2020, 2, 10), 3.1176470588235294], [Date.UTC(2020, 3, 3), 3.347826086956522], [Date.UTC(2020, 3, 18), 3.2758620689655173]], 'visible': False}]

# %%
from datetime import datetime
from pytz import utc 

def timestamp_from_str(date_str):

    date = datetime.strptime(date_str, '%Y-%m-%d %H:%M:%S') 
    return date.replace(tzinfo=utc).timestamp()

# %%
datetime.datetime(2018, 12, 19, 15, 32, 54, tzinfo=tzutc())
# Out:
# datetime.datetime(2018, 12, 19, 15, 32, 54, tzinfo=tzutc())

# %%
import datetime
from dateutil.tz import tzutc
import json

my_dictionary = {
    'Contents': [
        {
            'Key': 'filename-1.pdf',
            'LastModified': datetime.datetime(2018, 12, 19, 15, 32, 54, tzinfo=tzutc()),
            'Size': 1545033
        },
        {
            'Key': 'filename-2.pdf',
            'LastModified': datetime.datetime(2018, 12, 19, 15, 32, 54, tzinfo=tzutc()),
            'Size': 4222827
        },
        {
            'Key': 'filename-3.pdf',
            'LastModified': datetime.datetime(2018, 12, 19, 15, 32, 54, tzinfo=tzutc()),
            'Size': 640925
        },
        {
            'Key': 'filename-4.pdf',
            'LastModified': datetime.datetime(2018, 12, 19, 15, 32, 54, tzinfo=tzutc()),
            'Size': 1617724
        },
    ]
}


def convert_timestamp(item_date_object):
    if isinstance(item_date_object, (datetime.date, datetime.datetime)):
        return item_date_object.timestamp()


my_json_data = json.dumps(my_dictionary, default=convert_timestamp)

print(my_json_data)
# Out:
# {"Contents": [{"Key": "filename-1.pdf", "LastModified": 1545233574.0, "Size": 1545033}, {"Key": "filename-2.pdf", "LastModified": 1545233574.0, "Size": 4222827}, {"Key": "filename-3.pdf", "LastModified": 1545233574.0, "Size": 640925}, {"Key": "filename-4.pdf", "LastModified": 1545233574.0, "Size": 1617724}]}
